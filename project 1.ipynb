# %%
pip install panda
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np

# %%
import os

# %%
df = pd.read_csv("Womens Clothing E-Commerce Reviews.csv")
df
# Out:
#        Unnamed: 0  Clothing ID  Age  \
# 0               0          767   33
# 1               1         1080   34
# 2               2         1077   60
# 3               3         1049   50
# 4               4          847   47
# ...           ...          ...  ...
# 23481       23481         1104   34
# 23482       23482          862   48
# 23483       23483         1104   31
# 23484       23484         1084   28
# 23485       23485         1104   52
#
#                                                    Title  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                Some major design flaws
# 3                                       My favorite buy!
# 4                                       Flattering shirt
# ...                                                  ...
# 23481                     Great dress for many occasions
# 23482                         Wish it was made of cotton
# ...

# %%
df['Age']
# Out:
# 0        33
# 1        34
# 2        60
# 3        50
# 4        47
#          ..
# 23481    34
# 23482    48
# 23483    31
# 23484    28
# 23485    52
# Name: Age, Length: 23486, dtype: int64

# %%
# if i want the title to remove from my dataset 
df1 = df.drop('Title', axis=1, inplace=True)
df.head()
# Out:
#    Unnamed: 0  Clothing ID  Age  \
# 0           0          767   33
# 1           1         1080   34
# 2           2         1077   60
# 3           3         1049   50
# 4           4          847   47
#
#                                          Review Text  Rating  Recommended IND  \
# 0  Absolutely wonderful - silky and sexy and comf...       4                1
# 1  Love this dress!  it's sooo pretty.  i happene...       5                1
# 2  I had such high hopes for this dress and reall...       3                0
# 3  I love, love, love this jumpsuit. it's fun, fl...       5                1
# 4  This shirt is very flattering to all due to th...       5                1
#
#    Positive Feedback Count   Division Name Department Name Class Name
# 0                        0       Initmates        Intimate  Intimates
# 1                        4         General         Dresses    Dresses
# 2                        0         General         Dresses    Dresses
# ...

# %%
df.mean()
# Out:
# C:\Users\fasih\AppData\Local\Temp\ipykernel_10232\3698961737.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.mean()
# Unnamed: 0                 11742.500000
# Clothing ID                  918.118709
# Age                           43.198544
# Rating                         4.196032
# Recommended IND                0.822362
# Positive Feedback Count        2.535936
# dtype: float64

# %%
# Check the unique values in a column
unique_values = df['Age'].unique()
unique_values
# Out:
# array([33, 34, 60, 50, 47, 49, 39, 24, 53, 44, 41, 32, 55, 31, 28, 46, 21,
#        36, 65, 29, 38, 59, 40, 23, 67, 48, 43, 52, 56, 66, 61, 57, 58, 37,
#        27, 62, 68, 51, 83, 69, 54, 63, 71, 30, 35, 64, 42, 22, 26, 72, 25,
#        45, 74, 70, 20, 80, 93, 82, 77, 85, 73, 78, 79, 19, 76, 84, 75, 89,
#        81, 90, 94, 86, 99, 18, 91, 87, 92], dtype=int64)

# %%
# Check the unique values in a column
unique_values = df['Clothing ID'].unique()
unique_values
# Out:
# array([ 767, 1080, 1077, ...,  181,  721,  522], dtype=int64)

# %%
df_filtered = df[(df['Age'] > 90) & (df['Rating'] > 3)]
df_filtered
# Out:
#        Unnamed: 0  Clothing ID  Age  \
# 659           659          252   93
# 6543         6543         1095   94
# 8327         8327         1078   99
# 9513         9513          871   91
# 10686       10686         1002   91
# 11545       11545          949   99
# 14997       14997         1025   92
# 17578       17578          901   93
# 18563       18563         1094   94
#
#                                              Review Text  Rating  \
# 659    This is by far the cutest, most glamorous one ...       5
# 6543   Flattering! i love how it looks like a maxi dr...       4
# 8327   I love the weight of the material; sometimes c...       5
# 9513   From the website picture (in particular, the g...       5
# 10686                                                NaN       5
# 11545  Great quality, i didn't expect the neck to be ...       4
# 14997  It's hard to tell how jeans will fit when shop...       5
# 17578  Great quality. very versatile design and super...       4
# ...

# %%
df_filtered = df[df['Class Name'] == 'Swim']
df_filtered
# Out:
#        Unnamed: 0  Clothing ID  Age  \
# 157           157          523   43
# 216           216          305   46
# 455           455          234   33
# 611           611          252   35
# 619           619          252   36
# ...           ...          ...  ...
# 23089       23089         1167   39
# 23160       23160          400   34
# 23174       23174          400   31
# 23318       23318          345   39
# 23476       23476          522   27
#
#                                              Review Text  Rating  \
# 157    So  disappointed that no where in the limiting...       3
# 216    Bought a large, could barely pull up over my b...       2
# 455                                                  NaN       5
# 611                                                  NaN       4
# 619    Ordered the navy and aqua in medium. the aqua ...       4
# ...                                                  ...     ...
# 23089  The top of this suit was not proportioned well...       2
# ...

# %%
nan_values_age = df['Age'].isna()
nan_values_age
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 23481    False
# 23482    False
# 23483    False
# 23484    False
# 23485    False
# Name: Age, Length: 23486, dtype: bool

# %%
nan_values_age = df['Clothing ID'].isna()
nan_values_age
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 23481    False
# 23482    False
# 23483    False
# 23484    False
# 23485    False
# Name: Clothing ID, Length: 23486, dtype: bool

# %%
unique_values = df['Age'].unique()
unique_values
# Out:
# array([33, 34, 60, 50, 47, 49, 39, 24, 53, 44, 41, 32, 55, 31, 28, 46, 21,
#        36, 65, 29, 38, 59, 40, 23, 67, 48, 43, 52, 56, 66, 61, 57, 58, 37,
#        27, 62, 68, 51, 83, 69, 54, 63, 71, 30, 35, 64, 42, 22, 26, 72, 25,
#        45, 74, 70, 20, 80, 93, 82, 77, 85, 73, 78, 79, 19, 76, 84, 75, 89,
#        81, 90, 94, 86, 99, 18, 91, 87, 92], dtype=int64)

# %%
unique_values = df['Clothing ID'].unique()
unique_values
# Out:
# array([ 767, 1080, 1077, ...,  181,  721,  522], dtype=int64)

# %%
sorted_df = df.sort_values('Age', ascending=False)
sorted_df
# Out:
#        Unnamed: 0  Clothing ID  Age  \
# 8327         8327         1078   99
# 11545       11545          949   99
# 18563       18563         1094   94
# 18036       18036         1094   94
# 6543         6543         1095   94
# ...           ...          ...  ...
# 8354         8354         1098   19
# 22390       22390          868   18
# 22364       22364         1072   18
# 8858         8858         1094   18
# 19704       19704         1008   18
#
#                                              Review Text  Rating  \
# 8327   I love the weight of the material; sometimes c...       5
# 11545  Great quality, i didn't expect the neck to be ...       4
# 18563  This dress is very comfortable, not itchy at a...       5
# 18036  Dress just did not fit will around the hips.  ...       1
# 6543   Flattering! i love how it looks like a maxi dr...       4
# ...                                                  ...     ...
# 8354   This dress is so pretty!! the second i saw it ...       4
# ...

# %%
missing_values = df.isnull().any()
missing_values
# Out:
# Unnamed: 0                 False
# Clothing ID                False
# Age                        False
# Review Text                 True
# Rating                     False
# Recommended IND            False
# Positive Feedback Count    False
# Division Name               True
# Department Name             True
# Class Name                  True
# dtype: bool

# %%
is_column_null = df['Department Name'].isnull().any()
is_column_null
# Out:
# True

# %%
# Check for missing values in a specific column
missing_values = df['Department Name'].isnull()  

# Count the number of missing values
missing_count = missing_values.sum()

# Print the missing count
print("Missing values count:", missing_count)
# Out:
# Missing values count: 14

# %%
# Remove missing values from a specific column
df.dropna(subset=['Department Name'], inplace=True)

# Print the updated DataFrame
print(df)
# Out:
#        Unnamed: 0  Clothing ID  Age  \
# 0               0          767   33
# 1               1         1080   34
# 2               2         1077   60
# 3               3         1049   50
# 4               4          847   47
# ...           ...          ...  ...
# 23481       23481         1104   34
# 23482       23482          862   48
# 23483       23483         1104   31
# 23484       23484         1084   28
# 23485       23485         1104   52
#
#                                              Review Text  Rating  \
# 0      Absolutely wonderful - silky and sexy and comf...       4
# 1      Love this dress!  it's sooo pretty.  i happene...       5
# 2      I had such high hopes for this dress and reall...       3
# 3      I love, love, love this jumpsuit. it's fun, fl...       5
# 4      This shirt is very flattering to all due to th...       5
# ...                                                  ...     ...
# 23481  I was very happy to snag this dress at such a ...       5
# ...

# %%
missing_values = df['Department Name'].isnull()  

missing_count = missing_values.sum()

print("Missing values count:", missing_count)
# Out:
# Missing values count: 0

# %%
df
# Out:
#        Unnamed: 0  Clothing ID  Age  \
# 0               0          767   33
# 1               1         1080   34
# 2               2         1077   60
# 3               3         1049   50
# 4               4          847   47
# ...           ...          ...  ...
# 23481       23481         1104   34
# 23482       23482          862   48
# 23483       23483         1104   31
# 23484       23484         1084   28
# 23485       23485         1104   52
#
#                                              Review Text  Rating  \
# 0      Absolutely wonderful - silky and sexy and comf...       4
# 1      Love this dress!  it's sooo pretty.  i happene...       5
# 2      I had such high hopes for this dress and reall...       3
# 3      I love, love, love this jumpsuit. it's fun, fl...       5
# 4      This shirt is very flattering to all due to th...       5
# ...                                                  ...     ...
# 23481  I was very happy to snag this dress at such a ...       5
# ...

# %%
df.tail()
# Out:
#        Unnamed: 0  Clothing ID  Age  \
# 23481       23481         1104   34
# 23482       23482          862   48
# 23483       23483         1104   31
# 23484       23484         1084   28
# 23485       23485         1104   52
#
#                                              Review Text  Rating  \
# 23481  I was very happy to snag this dress at such a ...       5
# 23482  It reminds me of maternity clothes. soft, stre...       3
# 23483  This fit well, but the top was very see throug...       3
# 23484  I bought this dress for a wedding i have this ...       3
# 23485  This dress in a lovely platinum is feminine an...       5
#
#        Recommended IND  Positive Feedback Count   Division Name  \
# 23481                1                        0  General Petite
# 23482                1                        0  General Petite
# 23483                0                        1  General Petite
# 23484                1                        2         General
# ...

# %%
df.shape
# Out:
# (23472, 10)

# %%
print("Rows : ",df.shape[0])
print("columns : ",df.shape[1])
# Out:
# Rows :  23472
# columns :  10

# %%
df.shape[0]
# Out:
# 23472

# %%
df.shape[1]
# Out:
# 10

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23472 entries, 0 to 23485
# Data columns (total 10 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Unnamed: 0               23472 non-null  int64
#  1   Clothing ID              23472 non-null  int64
#  2   Age                      23472 non-null  int64
#  3   Review Text              22628 non-null  object
#  4   Rating                   23472 non-null  int64
#  5   Recommended IND          23472 non-null  int64
#  6   Positive Feedback Count  23472 non-null  int64
#  7   Division Name            23472 non-null  object
#  8   Department Name          23472 non-null  object
#  9   Class Name               23472 non-null  object
# dtypes: int64(6), object(4)
# memory usage: 2.0+ MB

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                   0
# Clothing ID                  0
# Age                          0
# Review Text                844
# Rating                       0
# Recommended IND              0
# Positive Feedback Count      0
# Division Name                0
# Department Name              0
# Class Name                   0
# dtype: int64

# %%
df1 = df.drop('Review Text', axis=1, inplace=True)
df
# Out:
#        Unnamed: 0  Clothing ID  Age  Rating  Recommended IND  \
# 0               0          767   33       4                1
# 1               1         1080   34       5                1
# 2               2         1077   60       3                0
# 3               3         1049   50       5                1
# 4               4          847   47       5                1
# ...           ...          ...  ...     ...              ...
# 23481       23481         1104   34       5                1
# 23482       23482          862   48       3                1
# 23483       23483         1104   31       3                0
# 23484       23484         1084   28       3                1
# 23485       23485         1104   52       5                1
#
#        Positive Feedback Count   Division Name Department Name Class Name
# 0                            0       Initmates        Intimate  Intimates
# 1                            4         General         Dresses    Dresses
# ...

# %%
df.describe(include="all")
# Out:
#           Unnamed: 0   Clothing ID           Age        Rating  \
# count   23472.000000  23472.000000  23472.000000  23472.000000
# unique           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN
# mean    11738.965491    918.486665     43.200707      4.195552
# std      6779.729976    202.727678     12.280913      1.110188
# min         0.000000      0.000000     18.000000      1.000000
# 25%      5867.750000    861.000000     34.000000      4.000000
# 50%     11736.500000    936.000000     41.000000      5.000000
# 75%     17610.250000   1078.000000     52.000000      5.000000
# max     23485.000000   1205.000000     99.000000      5.000000
#
#         Recommended IND  Positive Feedback Count Division Name  \
# count      23472.000000             23472.000000         23472
# unique              NaN                      NaN             3
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of        Unnamed: 0  Clothing ID  Age  Rating  Recommended IND  \
# 0               0          767   33       4                1
# 1               1         1080   34       5                1
# 2               2         1077   60       3                0
# 3               3         1049   50       5                1
# 4               4          847   47       5                1
# ...           ...          ...  ...     ...              ...
# 23481       23481         1104   34       5                1
# 23482       23482          862   48       3                1
# 23483       23483         1104   31       3                0
# 23484       23484         1084   28       3                1
# 23485       23485         1104   52       5                1
#
#        Positive Feedback Count   Division Name Department Name Class Name
# 0                            0       Initmates        Intimate  Intimates
# ...

# %%
len(df.Age.unique())
# Out:
# 77

# %%
df.value_counts()
# Out:
# Unnamed: 0  Clothing ID  Age  Rating  Recommended IND  Positive Feedback Count  Division Name   Department Name  Class Name
# 0           767          33   4       1                0                        Initmates       Intimate         Intimates     1
# 15659       1078         26   4       1                0                        General Petite  Dresses          Dresses       1
# 15657       909          54   5       1                0                        General         Tops             Fine gauge    1
# 15656       981          32   5       1                0                        General Petite  Jackets          Jackets       1
# 15655       513          57   5       1                1                        Initmates       Intimate         Swim          1
#                                                                                                                               ..
# ...

# %%
df.max()
# Out:
# Unnamed: 0                     23485
# Clothing ID                     1205
# Age                               99
# Rating                             5
# Recommended IND                    1
# Positive Feedback Count          122
# Division Name              Initmates
# Department Name                Trend
# Class Name                     Trend
# dtype: object

# %%
df.min()
# Out:
# Unnamed: 0                       0
# Clothing ID                      0
# Age                             18
# Rating                           1
# Recommended IND                  0
# Positive Feedback Count          0
# Division Name              General
# Department Name            Bottoms
# Class Name                 Blouses
# dtype: object

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                 0
# Clothing ID                0
# Age                        0
# Rating                     0
# Recommended IND            0
# Positive Feedback Count    0
# Division Name              0
# Department Name            0
# Class Name                 0
# dtype: int64

# %%
df
# Out:
#        Unnamed: 0  Clothing ID  Age  Rating  Recommended IND  \
# 0               0          767   33       4                1
# 1               1         1080   34       5                1
# 2               2         1077   60       3                0
# 3               3         1049   50       5                1
# 4               4          847   47       5                1
# ...           ...          ...  ...     ...              ...
# 23481       23481         1104   34       5                1
# 23482       23482          862   48       3                1
# 23483       23483         1104   31       3                0
# 23484       23484         1084   28       3                1
# 23485       23485         1104   52       5                1
#
#        Positive Feedback Count   Division Name Department Name Class Name
# 0                            0       Initmates        Intimate  Intimates
# 1                            4         General         Dresses    Dresses
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming you have a DataFrame called 'df' containing the data

# Count the occurrences of each category in 'Division Name'
division_counts = df['Division Name'].value_counts()

# Plot a bar chart of 'Division Name' counts
plt.bar(division_counts.index, division_counts.values)
plt.xlabel('Division Name')
plt.ylabel('Count')
plt.title('Distribution of Division Names')
plt.show()

# %%
plt.hist(df['Age'], bins=10)  # Adjust the number of bins as needed
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Age Distribution')
plt.show()

# %%
rating_counts = df['Rating'].value_counts()

plt.pie(rating_counts, labels=rating_counts.index, autopct='%1.1f%%')
plt.title('Rating Distribution')
plt.show()

# %%
plt.scatter(df['Age'], df['Positive Feedback Count'])
plt.xlabel('Age')
plt.ylabel('Positive Feedback Count')
plt.title('Age vs Positive Feedback Count')
plt.show()

# %%
cross_table = pd.crosstab(df['Division Name'], df['Recommended IND'])

cross_table.plot(kind='bar', stacked=True)
plt.xlabel('Division Name')
plt.ylabel('Count')
plt.title('Recommended IND by Division Name')
plt.show()

# %%
age_grouped = df.groupby('Age')['Positive Feedback Count'].mean()

plt.plot(age_grouped.index, age_grouped.values)
plt.xlabel('Age')
plt.ylabel('Mean Positive Feedback Count')
plt.title('Mean Positive Feedback Count by Age')
plt.show()
